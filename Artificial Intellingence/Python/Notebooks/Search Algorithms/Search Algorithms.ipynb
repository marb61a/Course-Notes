# %% [markdown]
# Linear Search

# %%
def linear_search_function(numVals, key):
    index = 0
    while index < len(A):
        if A[index] == key:
            return index
        index = index + 1
    return -1

A = [24, 48, 36, 12, 60, 72, 84]
foundVal = linear_search_function(A, 48)
print('The result is ', foundVal)
# Out:
# The result is  1

# %% [markdown]
# Binary Search Iterative Version

# %%
def binarysearch_iterative_function(numVals, key):
    # Starts the indices from both sides
    lIndex = 0
    rIndex = len(numVals) - 1
    while lIndex <= rIndex:
        # Need to be an integer to avoid issues
        midPoint = int((lIndex + rIndex) / 2)
        
        if(key == A[midPoint]):
            return midPoint
        elif(key < A[midPoint]):
            rIndex = midPoint - 1
        elif(key > A[midPoint]):
            lIndex = midPoint + 1
    return -1
    
A = [12, 24, 48, 36, 60, 72, 84]
foundVal = binarysearch_iterative_function(A, 60)
print('The result is ', foundVal)
# Out:
# The result is  4

# %% [markdown]
# Binary Search Recursive Algorithm

# %%
def binaryseaarch_recursive_function(numVals, key, lIndex, rIndex):
    if lIndex > rIndex:
        return -1
    else:
        # Need to be an integer to avoid issues
        midPoint = int((lIndex + rIndex) / 2)
        
        if key == A[midPoint]:
            return midPoint
        elif key < A[midPoint]:
            return binaryseaarch_recursive(A, key, lIndex, midPoint - 1)
        elif key > A[mid]:
            return binaryseaarch_recursive(A, key, midPoint + 1, rIndex)

A = [12, 24, 48, 36, 60, 72, 84, 96, 108]
foundVal = binaryseaarch_recursive_function(A, 36, 0, 6)
print('The result is ', foundVal)
# Out:
# The result is  3
